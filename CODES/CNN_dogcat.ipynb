# %%
import tensorflow as tf
from matplotlib import pyplot
from tensorflow.keras.datasets import fashion_mnist
from sklearn.model_selection import train_test_split

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau


import os,cv2
# Out:
# 2023-06-14 20:27:25.861967: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
train_path = "dog_cat/training_set/"
test_path = "dog_cat/test_set/"

img_size = 128

def get_data(path):
    data = []
    for filename in os.listdir(path):
        category = filename.split('.')[0]
        if category == 'dog':
            try:
                img_arr = cv2.imread(os.path.join(path,filename), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr,(img_size,img_size))
                data.append([resized_arr, 1])
            except Exception as e:
                print(e)
        else:
            try:
                img_arr = cv2.imread(os.path.join(path,filename), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr,(img_size,img_size))
                data.append([resized_arr, 0])
            except Exception as e:
                print(e)
    return data

train = get_data(train_path)
test = get_data(test_path)
# Out:
# OpenCV(4.7.0) /io/opencv/modules/imgproc/src/resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
import numpy as np
print(np.array(train,dtype='object').shape)
print(np.array(test,dtype='object').shape)
# Out:
# (8005, 2)
# (2023, 2)

# %%
x_train = []
y_train = []
x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label) 
print(np.array(x_train).shape)

#print test array
for feature, label in test:
    x_test.append(feature)
    y_test.append(label) 
print(np.array(x_test).shape)
  
del train
del test
# Out:
# (8005, 128, 128, 3)
# (2023, 128, 128, 3)

# %%
# # Normalize the data
import random as rn
x_train = np.array(x_train,dtype="float")/255.0
x_test = np.array(x_test,dtype="float")/255.0

# #label encoding the y array
y_train = to_categorical(y_train, 2) 
y_test = to_categorical(y_test, 2)

#Prepare data
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.20, shuffle=True, random_state=42)

np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

print(x_val.shape)
# Out:
# (1601, 128, 128, 3)

# %%
def create_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))


    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

# %%
datagen = ImageDataGenerator(        
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images)

datagen.fit(x_train)

# validgen = ImageDataGenerator(
#         featurewise_center=False,  # set input mean to 0 over the dataset
#         samplewise_center=False,  # set each sample mean to 0
#         featurewise_std_normalization=False,  # divide inputs by std of the dataset
#         samplewise_std_normalization=False,  # divide each input by its std
#         zca_whitening=False,  # apply ZCA whitening
#         rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
#         zoom_range = 0.1, # Randomly zoom image 
#         width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
#         height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
#         horizontal_flip=True,  # randomly flip images
#         vertical_flip=False)  # randomly flip images)
# validgen.fit(x_val)

# %%
model = create_model()
# model.summary()
# Out:
# 2023-06-14 20:27:44.690744: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-06-14 20:27:44.691527: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-06-14 20:27:44.730316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:68:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-06-14 20:27:44.730341: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-14 20:27:44.732934: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-06-14 20:27:44.732993: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-06-14 20:27:44.734999: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-06-14 20:27:44.735867: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-06-14 20:27:44.737214: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-06-14 20:27:44.738129: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-06-14 20:27:44.740850: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-06-14 20:27:44.741139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-06-14 20:27:44.741414: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-14 20:27:44.742380: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-06-14 20:27:44.742573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:68:00.0 name: NVIDIA GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.76GiB deviceMemoryBandwidth: 573.69GiB/s
# 2023-06-14 20:27:44.742586: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-14 20:27:44.742603: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-06-14 20:27:44.742610: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-06-14 20:27:44.742617: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-06-14 20:27:44.742624: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-06-14 20:27:44.742631: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-06-14 20:27:44.742637: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-06-14 20:27:44.742644: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-06-14 20:27:44.742861: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-06-14 20:27:44.742880: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-14 20:27:45.082342: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-06-14 20:27:45.082377: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2023-06-14 20:27:45.082381: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2023-06-14 20:27:45.082890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10075 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:68:00.0, compute capability: 7.5)

# %%
batch_size=32
early = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='auto')
checkpoint = ModelCheckpoint("dogcat_model.h5", monitor='val_accuracy', verbose=1, 
                             save_best_only=True, save_weights_only=False, mode='auto')
history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs = 50, validation_data = (x_val,y_val), callbacks=[checkpoint, early],
                    verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
#history = model.fit(x_train, y_train, epochs = 50, validation_data = (x_val,y_val), callbacks=[checkpoint, early],verbose = 1)
model.save("dogcat_model.h5")
# Out:
# 2023-06-14 20:27:45.590743: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-06-14 20:27:45.602966: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3700000000 Hz
# Epoch 1/50
# 2023-06-14 20:27:46.309716: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-06-14 20:27:46.443352: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-06-14 20:27:47.081103: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2023-06-14 20:27:47.112473: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 200/200 [==============================] - 24s 95ms/step - loss: 1.3549 - accuracy: 0.5551 - val_loss: 0.7356 - val_accuracy: 0.4997
#
# Epoch 00001: val_accuracy improved from -inf to 0.49969, saving model to dogcat_model.h5
# Epoch 2/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.7533 - accuracy: 0.5982 - val_loss: 0.7157 - val_accuracy: 0.5690
#
# Epoch 00002: val_accuracy improved from 0.49969 to 0.56902, saving model to dogcat_model.h5
# Epoch 3/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6705 - accuracy: 0.6339 - val_loss: 0.7770 - val_accuracy: 0.5834
#
# Epoch 00003: val_accuracy improved from 0.56902 to 0.58339, saving model to dogcat_model.h5
# Epoch 4/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.6215 - accuracy: 0.6751 - val_loss: 0.7186 - val_accuracy: 0.6446
#
# Epoch 00004: val_accuracy improved from 0.58339 to 0.64460, saving model to dogcat_model.h5
# Epoch 5/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.5840 - accuracy: 0.6938 - val_loss: 0.5906 - val_accuracy: 0.6989
#
# Epoch 00005: val_accuracy improved from 0.64460 to 0.69894, saving model to dogcat_model.h5
# Epoch 6/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.5663 - accuracy: 0.7117 - val_loss: 0.5095 - val_accuracy: 0.7458
#
# Epoch 00006: val_accuracy improved from 0.69894 to 0.74578, saving model to dogcat_model.h5
# Epoch 7/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.5313 - accuracy: 0.7472 - val_loss: 0.7428 - val_accuracy: 0.6440
#
# Epoch 00007: val_accuracy did not improve from 0.74578
# Epoch 8/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.5240 - accuracy: 0.7314 - val_loss: 0.4922 - val_accuracy: 0.7577
#
# Epoch 00008: val_accuracy improved from 0.74578 to 0.75765, saving model to dogcat_model.h5
# Epoch 9/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.4986 - accuracy: 0.7592 - val_loss: 0.4746 - val_accuracy: 0.7676
#
# Epoch 00009: val_accuracy improved from 0.75765 to 0.76765, saving model to dogcat_model.h5
# Epoch 10/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.4952 - accuracy: 0.7596 - val_loss: 0.7732 - val_accuracy: 0.6683
#
# Epoch 00010: val_accuracy did not improve from 0.76765
# Epoch 11/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.4744 - accuracy: 0.7774 - val_loss: 0.4823 - val_accuracy: 0.7920
#
# Epoch 00011: val_accuracy improved from 0.76765 to 0.79201, saving model to dogcat_model.h5
# Epoch 12/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.4521 - accuracy: 0.7858 - val_loss: 0.4633 - val_accuracy: 0.7870
#
# Epoch 00012: val_accuracy did not improve from 0.79201
# Epoch 13/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.4364 - accuracy: 0.8042 - val_loss: 0.4518 - val_accuracy: 0.7876
#
# Epoch 00013: val_accuracy did not improve from 0.79201
# Epoch 14/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.4460 - accuracy: 0.7986 - val_loss: 1.7337 - val_accuracy: 0.6721
#
# Epoch 00014: val_accuracy did not improve from 0.79201
# Epoch 15/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.4387 - accuracy: 0.7991 - val_loss: 0.4035 - val_accuracy: 0.8207
#
# Epoch 00015: val_accuracy improved from 0.79201 to 0.82074, saving model to dogcat_model.h5
# Epoch 16/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.4116 - accuracy: 0.8051 - val_loss: 0.4131 - val_accuracy: 0.8057
#
# Epoch 00016: val_accuracy did not improve from 0.82074
# Epoch 17/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3895 - accuracy: 0.8187 - val_loss: 0.3919 - val_accuracy: 0.8232
#
# Epoch 00017: val_accuracy improved from 0.82074 to 0.82324, saving model to dogcat_model.h5
# Epoch 18/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3954 - accuracy: 0.8250 - val_loss: 0.4477 - val_accuracy: 0.8126
#
# Epoch 00018: val_accuracy did not improve from 0.82324
# Epoch 19/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3894 - accuracy: 0.8264 - val_loss: 0.4776 - val_accuracy: 0.7708
#
# Epoch 00019: val_accuracy did not improve from 0.82324
# Epoch 20/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3706 - accuracy: 0.8274 - val_loss: 0.7005 - val_accuracy: 0.6946
#
# Epoch 00020: val_accuracy did not improve from 0.82324
# Epoch 21/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3876 - accuracy: 0.8321 - val_loss: 0.3400 - val_accuracy: 0.8588
#
# Epoch 00021: val_accuracy improved from 0.82324 to 0.85884, saving model to dogcat_model.h5
# Epoch 22/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3645 - accuracy: 0.8327 - val_loss: 0.5409 - val_accuracy: 0.7583
#
# Epoch 00022: val_accuracy did not improve from 0.85884
# Epoch 23/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3629 - accuracy: 0.8403 - val_loss: 0.4149 - val_accuracy: 0.8251
#
# Epoch 00023: val_accuracy did not improve from 0.85884
# Epoch 24/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3690 - accuracy: 0.8385 - val_loss: 0.3952 - val_accuracy: 0.8270
#
# Epoch 00024: val_accuracy did not improve from 0.85884
# Epoch 25/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3655 - accuracy: 0.8365 - val_loss: 0.3857 - val_accuracy: 0.8320
#
# Epoch 00025: val_accuracy did not improve from 0.85884
# Epoch 26/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3533 - accuracy: 0.8507 - val_loss: 0.3205 - val_accuracy: 0.8626
#
# Epoch 00026: val_accuracy improved from 0.85884 to 0.86259, saving model to dogcat_model.h5
# Epoch 27/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3406 - accuracy: 0.8524 - val_loss: 0.4237 - val_accuracy: 0.8295
#
# Epoch 00027: val_accuracy did not improve from 0.86259
# Epoch 28/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3502 - accuracy: 0.8479 - val_loss: 0.4435 - val_accuracy: 0.8132
#
# Epoch 00028: val_accuracy did not improve from 0.86259
# Epoch 29/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3367 - accuracy: 0.8553 - val_loss: 0.3177 - val_accuracy: 0.8676
#
# Epoch 00029: val_accuracy improved from 0.86259 to 0.86758, saving model to dogcat_model.h5
# Epoch 30/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3372 - accuracy: 0.8529 - val_loss: 0.3153 - val_accuracy: 0.8738
#
# Epoch 00030: val_accuracy improved from 0.86758 to 0.87383, saving model to dogcat_model.h5
# Epoch 31/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3169 - accuracy: 0.8636 - val_loss: 0.3673 - val_accuracy: 0.8563
#
# Epoch 00031: val_accuracy did not improve from 0.87383
# Epoch 32/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3334 - accuracy: 0.8498 - val_loss: 0.3520 - val_accuracy: 0.8389
#
# Epoch 00032: val_accuracy did not improve from 0.87383
# Epoch 33/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3154 - accuracy: 0.8613 - val_loss: 0.6553 - val_accuracy: 0.7408
#
# Epoch 00033: val_accuracy did not improve from 0.87383
# Epoch 34/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3171 - accuracy: 0.8676 - val_loss: 0.3797 - val_accuracy: 0.8520
#
# Epoch 00034: val_accuracy did not improve from 0.87383
# Epoch 35/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3285 - accuracy: 0.8595 - val_loss: 0.4878 - val_accuracy: 0.7308
#
# Epoch 00035: val_accuracy did not improve from 0.87383
# Epoch 36/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3128 - accuracy: 0.8623 - val_loss: 0.4327 - val_accuracy: 0.8157
#
# Epoch 00036: val_accuracy did not improve from 0.87383
# Epoch 37/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3020 - accuracy: 0.8720 - val_loss: 0.2783 - val_accuracy: 0.8851
#
# Epoch 00037: val_accuracy improved from 0.87383 to 0.88507, saving model to dogcat_model.h5
# Epoch 38/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2936 - accuracy: 0.8731 - val_loss: 0.4680 - val_accuracy: 0.7664
#
# Epoch 00038: val_accuracy did not improve from 0.88507
# Epoch 39/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3176 - accuracy: 0.8700 - val_loss: 0.3573 - val_accuracy: 0.8613
#
# Epoch 00039: val_accuracy did not improve from 0.88507
# Epoch 40/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.3098 - accuracy: 0.8710 - val_loss: 0.4020 - val_accuracy: 0.8551
#
# Epoch 00040: val_accuracy did not improve from 0.88507
# Epoch 41/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2954 - accuracy: 0.8743 - val_loss: 0.4060 - val_accuracy: 0.8357
#
# Epoch 00041: val_accuracy did not improve from 0.88507
# Epoch 42/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2942 - accuracy: 0.8785 - val_loss: 0.4246 - val_accuracy: 0.8176
#
# Epoch 00042: val_accuracy did not improve from 0.88507
# Epoch 43/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2947 - accuracy: 0.8783 - val_loss: 0.4308 - val_accuracy: 0.8301
#
# Epoch 00043: val_accuracy did not improve from 0.88507
# Epoch 44/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2975 - accuracy: 0.8726 - val_loss: 0.2613 - val_accuracy: 0.8932
#
# Epoch 00044: val_accuracy improved from 0.88507 to 0.89319, saving model to dogcat_model.h5
# Epoch 45/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2969 - accuracy: 0.8711 - val_loss: 0.3671 - val_accuracy: 0.8507
#
# Epoch 00045: val_accuracy did not improve from 0.89319
# Epoch 46/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2755 - accuracy: 0.8866 - val_loss: 0.2921 - val_accuracy: 0.8801
#
# Epoch 00046: val_accuracy did not improve from 0.89319
# Epoch 47/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2989 - accuracy: 0.8683 - val_loss: 0.3597 - val_accuracy: 0.8682
#
# Epoch 00047: val_accuracy did not improve from 0.89319
# Epoch 48/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2893 - accuracy: 0.8781 - val_loss: 0.4127 - val_accuracy: 0.8301
#
# Epoch 00048: val_accuracy did not improve from 0.89319
# Epoch 49/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2906 - accuracy: 0.8740 - val_loss: 0.3001 - val_accuracy: 0.8832
#
# Epoch 00049: val_accuracy did not improve from 0.89319
# Epoch 50/50
# 200/200 [==============================] - 14s 69ms/step - loss: 0.2981 - accuracy: 0.8697 - val_loss: 0.3284 - val_accuracy: 0.8751
#
# Epoch 00050: val_accuracy did not improve from 0.89319

# %%
_,acc = model.evaluate(x_test, y_test, verbose=0)
print('test:',acc)
_,acc = model.evaluate(x_train, y_train, verbose=0)
print('train:',acc)
_,acc = model.evaluate(x_val, y_val, verbose=0)
print('val:',acc)
# Out:
# test: 0.8868017792701721
# train: 0.9128669500350952
# val: 0.8750780820846558

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']


pyplot.figure(figsize=(15, 15))
pyplot.subplot(2, 2, 1)
pyplot.plot(acc, color="blue", label='Training Accuracy')
pyplot.plot(val_acc, color="orange", label='Validation Accuracy')
pyplot.legend(loc='lower right')
pyplot.title('Training and Validation Accuracy')

pyplot.subplot(2, 2, 2)
pyplot.plot(loss, color="blue", label='Training Loss')
pyplot.plot(val_loss, color="orange", label='Validation Loss')
pyplot.legend(loc='upper right')
pyplot.title('Training and Validation Loss')
pyplot.show()

# %%
model1 = load_model("dogcat_model.h5")
model1_last_layer_output = Model(inputs=model1.input, outputs=model1.layers[-2].output)
model1_last_layer_output_train = model1_last_layer_output.predict(x_train, batch_size=32)
model1_last_layer_output_val = model1_last_layer_output.predict(x_val, batch_size=32)
model1_last_layer_output_test = model1_last_layer_output.predict(x_test, batch_size=32)


model2 = Sequential()

model2.add(Dense(2, activation='softmax'))
    # compile model
model2.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

early = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='auto')
checkpoint = ModelCheckpoint("dogcat_model2.h5", monitor='val_accuracy', verbose=1, 
                             save_best_only=True, save_weights_only=False, mode='auto')

model2.fit(model1_last_layer_output_train, y_train, epochs=50, validation_data=(model1_last_layer_output_val, y_val),callbacks=[checkpoint, early], batch_size=32)


_,acc = model2.evaluate(model1_last_layer_output_test, y_test, verbose=0)
print("test:",acc)
_, acc = model2.evaluate(model1_last_layer_output_train, y_train, verbose=0)
print("train:",acc)
_,acc = model2.evaluate(model1_last_layer_output_val, y_val, verbose=0)
print("val:",acc)


del model1_last_layer_output_train
del model1_last_layer_output_val
del model1_last_layer_output_test
del model1, model2
tf.keras.backend.clear_session()
# Out:
# Epoch 1/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.3329 - accuracy: 0.8492 - val_loss: 0.3348 - val_accuracy: 0.8844
#
# Epoch 00001: val_accuracy improved from -inf to 0.88445, saving model to dogcat_model2.h5
# Epoch 2/50
# 201/201 [==============================] - 0s 967us/step - loss: 0.2213 - accuracy: 0.9110 - val_loss: 0.3143 - val_accuracy: 0.8826
#
# Epoch 00002: val_accuracy did not improve from 0.88445
# Epoch 3/50
# 201/201 [==============================] - 0s 967us/step - loss: 0.2003 - accuracy: 0.9231 - val_loss: 0.2990 - val_accuracy: 0.8882
#
# Epoch 00003: val_accuracy improved from 0.88445 to 0.88819, saving model to dogcat_model2.h5
# Epoch 4/50
# 201/201 [==============================] - 0s 951us/step - loss: 0.1881 - accuracy: 0.9283 - val_loss: 0.3035 - val_accuracy: 0.8863
#
# Epoch 00004: val_accuracy did not improve from 0.88819
# Epoch 5/50
# 201/201 [==============================] - 0s 958us/step - loss: 0.1904 - accuracy: 0.9215 - val_loss: 0.3189 - val_accuracy: 0.8826
#
# Epoch 00005: val_accuracy did not improve from 0.88819
# Epoch 6/50
# 201/201 [==============================] - 0s 970us/step - loss: 0.1857 - accuracy: 0.9292 - val_loss: 0.3047 - val_accuracy: 0.8907
#
# Epoch 00006: val_accuracy improved from 0.88819 to 0.89069, saving model to dogcat_model2.h5
# Epoch 7/50
# 201/201 [==============================] - 0s 960us/step - loss: 0.1890 - accuracy: 0.9242 - val_loss: 0.2993 - val_accuracy: 0.8844
#
# Epoch 00007: val_accuracy did not improve from 0.89069
# Epoch 8/50
# 201/201 [==============================] - 0s 974us/step - loss: 0.1799 - accuracy: 0.9314 - val_loss: 0.3062 - val_accuracy: 0.8857
#
# Epoch 00008: val_accuracy did not improve from 0.89069
# Epoch 9/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1849 - accuracy: 0.9280 - val_loss: 0.3119 - val_accuracy: 0.8919
#
# Epoch 00009: val_accuracy improved from 0.89069 to 0.89194, saving model to dogcat_model2.h5
# Epoch 10/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1737 - accuracy: 0.9304 - val_loss: 0.2970 - val_accuracy: 0.8969
#
# Epoch 00010: val_accuracy improved from 0.89194 to 0.89694, saving model to dogcat_model2.h5
# Epoch 11/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1680 - accuracy: 0.9357 - val_loss: 0.2960 - val_accuracy: 0.8957
#
# Epoch 00011: val_accuracy did not improve from 0.89694
# Epoch 12/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1735 - accuracy: 0.9226 - val_loss: 0.3334 - val_accuracy: 0.8745
#
# Epoch 00012: val_accuracy did not improve from 0.89694
# Epoch 13/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1659 - accuracy: 0.9330 - val_loss: 0.3093 - val_accuracy: 0.8938
#
# Epoch 00013: val_accuracy did not improve from 0.89694
# Epoch 14/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1738 - accuracy: 0.9284 - val_loss: 0.3004 - val_accuracy: 0.8932
#
# Epoch 00014: val_accuracy did not improve from 0.89694
# Epoch 15/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1668 - accuracy: 0.9360 - val_loss: 0.3075 - val_accuracy: 0.8938
#
# Epoch 00015: val_accuracy did not improve from 0.89694
# Epoch 16/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1696 - accuracy: 0.9299 - val_loss: 0.3087 - val_accuracy: 0.8938
#
# Epoch 00016: val_accuracy did not improve from 0.89694
# Epoch 17/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1691 - accuracy: 0.9306 - val_loss: 0.3313 - val_accuracy: 0.8757
#
# Epoch 00017: val_accuracy did not improve from 0.89694
# Epoch 18/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1711 - accuracy: 0.9317 - val_loss: 0.3044 - val_accuracy: 0.8932
#
# Epoch 00018: val_accuracy did not improve from 0.89694
# Epoch 19/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1697 - accuracy: 0.9286 - val_loss: 0.3102 - val_accuracy: 0.8926
#
# Epoch 00019: val_accuracy did not improve from 0.89694
# Epoch 20/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1654 - accuracy: 0.9343 - val_loss: 0.3096 - val_accuracy: 0.8926
#
# Epoch 00020: val_accuracy did not improve from 0.89694
# Epoch 00020: early stopping
# test: 0.8922392725944519
# train: 0.9331667423248291
# val: 0.8925671577453613

# %%
model1 = load_model("dogcat_model.h5")
model1_last_layer_output = Model(inputs=model1.input, outputs=model1.layers[-2].output)
model1_last_layer_output_train = model1_last_layer_output.predict(x_train, batch_size=32)
model1_last_layer_output_val = model1_last_layer_output.predict(x_val, batch_size=32)
model1_last_layer_output_test = model1_last_layer_output.predict(x_test, batch_size=32)


model2 = Sequential()

model2.add(Dense(2, activation='softmax'))
    # compile model
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

early = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='auto')
checkpoint = ModelCheckpoint("dogcat_model3.h5", monitor='val_accuracy', verbose=1, 
                             save_best_only=True, save_weights_only=False, mode='auto')

model2.fit(model1_last_layer_output_train, y_train, epochs=50, validation_data=(model1_last_layer_output_val, y_val),callbacks=[checkpoint, early], batch_size=32)


_,acc = model2.evaluate(model1_last_layer_output_test, y_test, verbose=0)
print("test:",acc)
_, acc = model2.evaluate(model1_last_layer_output_train, y_train, verbose=0)
print("train:",acc)
_,acc = model2.evaluate(model1_last_layer_output_val, y_val, verbose=0)
print("val:",acc)


del model1_last_layer_output_train
del model1_last_layer_output_val
del model1_last_layer_output_test
del model1, model2
tf.keras.backend.clear_session()
# Out:
# Epoch 1/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.3309 - accuracy: 0.8466 - val_loss: 0.3251 - val_accuracy: 0.8819
#
# Epoch 00001: val_accuracy improved from -inf to 0.88195, saving model to dogcat_model3.h5
# Epoch 2/50
# 201/201 [==============================] - 0s 915us/step - loss: 0.2251 - accuracy: 0.9134 - val_loss: 0.3141 - val_accuracy: 0.8876
#
# Epoch 00002: val_accuracy improved from 0.88195 to 0.88757, saving model to dogcat_model3.h5
# Epoch 3/50
# 201/201 [==============================] - 0s 909us/step - loss: 0.2067 - accuracy: 0.9206 - val_loss: 0.2991 - val_accuracy: 0.8919
#
# Epoch 00003: val_accuracy improved from 0.88757 to 0.89194, saving model to dogcat_model3.h5
# Epoch 4/50
# 201/201 [==============================] - 0s 907us/step - loss: 0.1881 - accuracy: 0.9291 - val_loss: 0.2935 - val_accuracy: 0.8938
#
# Epoch 00004: val_accuracy improved from 0.89194 to 0.89382, saving model to dogcat_model3.h5
# Epoch 5/50
# 201/201 [==============================] - 0s 903us/step - loss: 0.1910 - accuracy: 0.9208 - val_loss: 0.2959 - val_accuracy: 0.8919
#
# Epoch 00005: val_accuracy did not improve from 0.89382
# Epoch 6/50
# 201/201 [==============================] - 0s 907us/step - loss: 0.1876 - accuracy: 0.9231 - val_loss: 0.3006 - val_accuracy: 0.8851
#
# Epoch 00006: val_accuracy did not improve from 0.89382
# Epoch 7/50
# 201/201 [==============================] - 0s 913us/step - loss: 0.1867 - accuracy: 0.9241 - val_loss: 0.2942 - val_accuracy: 0.8913
#
# Epoch 00007: val_accuracy did not improve from 0.89382
# Epoch 8/50
# 201/201 [==============================] - 0s 901us/step - loss: 0.1793 - accuracy: 0.9280 - val_loss: 0.2984 - val_accuracy: 0.8869
#
# Epoch 00008: val_accuracy did not improve from 0.89382
# Epoch 9/50
# 201/201 [==============================] - 0s 932us/step - loss: 0.1873 - accuracy: 0.9226 - val_loss: 0.3002 - val_accuracy: 0.8969
#
# Epoch 00009: val_accuracy improved from 0.89382 to 0.89694, saving model to dogcat_model3.h5
# Epoch 10/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1722 - accuracy: 0.9303 - val_loss: 0.2902 - val_accuracy: 0.8963
#
# Epoch 00010: val_accuracy did not improve from 0.89694
# Epoch 11/50
# 201/201 [==============================] - 0s 969us/step - loss: 0.1679 - accuracy: 0.9350 - val_loss: 0.2963 - val_accuracy: 0.8969
#
# Epoch 00011: val_accuracy did not improve from 0.89694
# Epoch 12/50
# 201/201 [==============================] - 0s 971us/step - loss: 0.1761 - accuracy: 0.9226 - val_loss: 0.2917 - val_accuracy: 0.8957
#
# Epoch 00012: val_accuracy did not improve from 0.89694
# Epoch 13/50
# 201/201 [==============================] - 0s 966us/step - loss: 0.1647 - accuracy: 0.9332 - val_loss: 0.2987 - val_accuracy: 0.9001
#
# Epoch 00013: val_accuracy improved from 0.89694 to 0.90006, saving model to dogcat_model3.h5
# Epoch 14/50
# 201/201 [==============================] - 0s 980us/step - loss: 0.1695 - accuracy: 0.9297 - val_loss: 0.2917 - val_accuracy: 0.8957
#
# Epoch 00014: val_accuracy did not improve from 0.90006
# Epoch 15/50
# 201/201 [==============================] - 0s 971us/step - loss: 0.1669 - accuracy: 0.9330 - val_loss: 0.2995 - val_accuracy: 0.8994
#
# Epoch 00015: val_accuracy did not improve from 0.90006
# Epoch 16/50
# 201/201 [==============================] - 0s 970us/step - loss: 0.1695 - accuracy: 0.9280 - val_loss: 0.2976 - val_accuracy: 0.8994
#
# Epoch 00016: val_accuracy did not improve from 0.90006
# Epoch 17/50
# 201/201 [==============================] - 0s 955us/step - loss: 0.1706 - accuracy: 0.9300 - val_loss: 0.3057 - val_accuracy: 0.8901
#
# Epoch 00017: val_accuracy did not improve from 0.90006
# Epoch 18/50
# 201/201 [==============================] - 0s 966us/step - loss: 0.1736 - accuracy: 0.9296 - val_loss: 0.2989 - val_accuracy: 0.8926
#
# Epoch 00018: val_accuracy did not improve from 0.90006
# Epoch 19/50
# 201/201 [==============================] - 0s 967us/step - loss: 0.1655 - accuracy: 0.9326 - val_loss: 0.2981 - val_accuracy: 0.8957
#
# Epoch 00019: val_accuracy did not improve from 0.90006
# Epoch 20/50
# 201/201 [==============================] - 0s 966us/step - loss: 0.1661 - accuracy: 0.9356 - val_loss: 0.3042 - val_accuracy: 0.8982
#
# Epoch 00020: val_accuracy did not improve from 0.90006
# Epoch 21/50
# 201/201 [==============================] - 0s 975us/step - loss: 0.1694 - accuracy: 0.9298 - val_loss: 0.3071 - val_accuracy: 0.8919
#
# Epoch 00021: val_accuracy did not improve from 0.90006
# Epoch 22/50
# 201/201 [==============================] - 0s 964us/step - loss: 0.1547 - accuracy: 0.9377 - val_loss: 0.3067 - val_accuracy: 0.8969
#
# Epoch 00022: val_accuracy did not improve from 0.90006
# Epoch 23/50
# 201/201 [==============================] - 0s 965us/step - loss: 0.1610 - accuracy: 0.9342 - val_loss: 0.3078 - val_accuracy: 0.8982
#
# Epoch 00023: val_accuracy did not improve from 0.90006
# Epoch 00023: early stopping
# test: 0.8912506103515625
# train: 0.9339475035667419
# val: 0.8981886506080627

# %%
model1 = load_model("dogcat_model.h5")
model1_last_layer_output = Model(inputs=model1.input, outputs=model1.layers[-2].output)
model1_last_layer_output_train = model1_last_layer_output.predict(x_train, batch_size=32)
model1_last_layer_output_val = model1_last_layer_output.predict(x_val, batch_size=32)
model1_last_layer_output_test = model1_last_layer_output.predict(x_test, batch_size=32)


model2 = Sequential()
model2.add(Dense(2, activation='softmax'))
# compile model
opt = SGD(learning_rate=0.001, momentum=0.9)
model2.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

early = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, mode='auto')
checkpoint = ModelCheckpoint("dogcat_model4.h5", monitor='val_accuracy', verbose=1, 
                             save_best_only=True, save_weights_only=False, mode='auto')

model2.fit(model1_last_layer_output_train, y_train, epochs=50, validation_data=(model1_last_layer_output_val, y_val), callbacks=[checkpoint, early], batch_size=32)


_,acc = model2.evaluate(model1_last_layer_output_test, y_test, verbose=0)
print("test:",acc)
_, acc = model2.evaluate(model1_last_layer_output_train, y_train, verbose=0)
print("train:",acc)
_,acc = model2.evaluate(model1_last_layer_output_val, y_val, verbose=0)
print("val:",acc)

del model1_last_layer_output
del model1_last_layer_output_train
del model1_last_layer_output_val
del model1_last_layer_output_test
del model1
tf.keras.backend.clear_session()
# Out:
# Epoch 1/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.3291 - accuracy: 0.8635 - val_loss: 0.3288 - val_accuracy: 0.8745
#
# Epoch 00001: val_accuracy improved from -inf to 0.87445, saving model to dogcat_model4.h5
# Epoch 2/50
# 201/201 [==============================] - 0s 919us/step - loss: 0.2348 - accuracy: 0.9074 - val_loss: 0.3249 - val_accuracy: 0.8819
#
# Epoch 00002: val_accuracy improved from 0.87445 to 0.88195, saving model to dogcat_model4.h5
# Epoch 3/50
# 201/201 [==============================] - 0s 921us/step - loss: 0.2216 - accuracy: 0.9150 - val_loss: 0.3217 - val_accuracy: 0.8826
#
# Epoch 00003: val_accuracy improved from 0.88195 to 0.88257, saving model to dogcat_model4.h5
# Epoch 4/50
# 201/201 [==============================] - 0s 933us/step - loss: 0.2080 - accuracy: 0.9224 - val_loss: 0.3151 - val_accuracy: 0.8857
#
# Epoch 00004: val_accuracy improved from 0.88257 to 0.88570, saving model to dogcat_model4.h5
# Epoch 5/50
# 201/201 [==============================] - 0s 927us/step - loss: 0.2139 - accuracy: 0.9147 - val_loss: 0.3125 - val_accuracy: 0.8869
#
# Epoch 00005: val_accuracy improved from 0.88570 to 0.88695, saving model to dogcat_model4.h5
# Epoch 6/50
# 201/201 [==============================] - 0s 923us/step - loss: 0.2089 - accuracy: 0.9219 - val_loss: 0.3121 - val_accuracy: 0.8882
#
# Epoch 00006: val_accuracy improved from 0.88695 to 0.88819, saving model to dogcat_model4.h5
# Epoch 7/50
# 201/201 [==============================] - 0s 921us/step - loss: 0.2119 - accuracy: 0.9180 - val_loss: 0.3103 - val_accuracy: 0.8876
#
# Epoch 00007: val_accuracy did not improve from 0.88819
# Epoch 8/50
# 201/201 [==============================] - 0s 935us/step - loss: 0.2053 - accuracy: 0.9229 - val_loss: 0.3071 - val_accuracy: 0.8894
#
# Epoch 00008: val_accuracy improved from 0.88819 to 0.88944, saving model to dogcat_model4.h5
# Epoch 9/50
# 201/201 [==============================] - 0s 985us/step - loss: 0.2128 - accuracy: 0.9197 - val_loss: 0.3069 - val_accuracy: 0.8894
#
# Epoch 00009: val_accuracy did not improve from 0.88944
# Epoch 10/50
# 201/201 [==============================] - 0s 1ms/step - loss: 0.1970 - accuracy: 0.9235 - val_loss: 0.3078 - val_accuracy: 0.8857
#
# Epoch 00010: val_accuracy did not improve from 0.88944
# Epoch 11/50
# 201/201 [==============================] - 0s 987us/step - loss: 0.1939 - accuracy: 0.9296 - val_loss: 0.3027 - val_accuracy: 0.8913
#
# Epoch 00011: val_accuracy improved from 0.88944 to 0.89132, saving model to dogcat_model4.h5
# Epoch 12/50
# 201/201 [==============================] - 0s 978us/step - loss: 0.2010 - accuracy: 0.9193 - val_loss: 0.3007 - val_accuracy: 0.8913
#
# Epoch 00012: val_accuracy did not improve from 0.89132
# Epoch 13/50
# 201/201 [==============================] - 0s 985us/step - loss: 0.1888 - accuracy: 0.9309 - val_loss: 0.3013 - val_accuracy: 0.8907
#
# Epoch 00013: val_accuracy did not improve from 0.89132
# Epoch 14/50
# 201/201 [==============================] - 0s 987us/step - loss: 0.1952 - accuracy: 0.9254 - val_loss: 0.3005 - val_accuracy: 0.8926
#
# Epoch 00014: val_accuracy improved from 0.89132 to 0.89257, saving model to dogcat_model4.h5
# Epoch 15/50
# 201/201 [==============================] - 0s 985us/step - loss: 0.1887 - accuracy: 0.9296 - val_loss: 0.2996 - val_accuracy: 0.8913
#
# Epoch 00015: val_accuracy did not improve from 0.89257
# Epoch 16/50
# 201/201 [==============================] - 0s 987us/step - loss: 0.1983 - accuracy: 0.9172 - val_loss: 0.2975 - val_accuracy: 0.8894
#
# Epoch 00016: val_accuracy did not improve from 0.89257
# Epoch 17/50
# 201/201 [==============================] - 0s 974us/step - loss: 0.1981 - accuracy: 0.9240 - val_loss: 0.2977 - val_accuracy: 0.8894
#
# Epoch 00017: val_accuracy did not improve from 0.89257
# Epoch 18/50
# 201/201 [==============================] - 0s 973us/step - loss: 0.1950 - accuracy: 0.9254 - val_loss: 0.2964 - val_accuracy: 0.8907
#
# Epoch 00018: val_accuracy did not improve from 0.89257
# Epoch 19/50
# 201/201 [==============================] - 0s 965us/step - loss: 0.1948 - accuracy: 0.9240 - val_loss: 0.2974 - val_accuracy: 0.8919
#
# Epoch 00019: val_accuracy did not improve from 0.89257
# Epoch 20/50
# 201/201 [==============================] - 0s 972us/step - loss: 0.1900 - accuracy: 0.9282 - val_loss: 0.3006 - val_accuracy: 0.8913
#
# Epoch 00020: val_accuracy did not improve from 0.89257
# Epoch 21/50
# 201/201 [==============================] - 0s 982us/step - loss: 0.1962 - accuracy: 0.9264 - val_loss: 0.2969 - val_accuracy: 0.8932
#
# Epoch 00021: val_accuracy improved from 0.89257 to 0.89319, saving model to dogcat_model4.h5
# Epoch 22/50
# 201/201 [==============================] - 0s 979us/step - loss: 0.1791 - accuracy: 0.9274 - val_loss: 0.2955 - val_accuracy: 0.8919
#
# Epoch 00022: val_accuracy did not improve from 0.89319
# Epoch 23/50
# 201/201 [==============================] - 0s 973us/step - loss: 0.1891 - accuracy: 0.9260 - val_loss: 0.2943 - val_accuracy: 0.8907
#
# Epoch 00023: val_accuracy did not improve from 0.89319
# Epoch 24/50
# 201/201 [==============================] - 0s 991us/step - loss: 0.1802 - accuracy: 0.9328 - val_loss: 0.2957 - val_accuracy: 0.8913
#
# Epoch 00024: val_accuracy did not improve from 0.89319
# Epoch 25/50
# 201/201 [==============================] - 0s 968us/step - loss: 0.1908 - accuracy: 0.9222 - val_loss: 0.2950 - val_accuracy: 0.8932
#
# Epoch 00025: val_accuracy did not improve from 0.89319
# Epoch 26/50
# 201/201 [==============================] - 0s 978us/step - loss: 0.1798 - accuracy: 0.9279 - val_loss: 0.2970 - val_accuracy: 0.8932
#
# Epoch 00026: val_accuracy did not improve from 0.89319
# Epoch 27/50
# 201/201 [==============================] - 0s 986us/step - loss: 0.1840 - accuracy: 0.9229 - val_loss: 0.2929 - val_accuracy: 0.8907
#
# Epoch 00027: val_accuracy did not improve from 0.89319
# Epoch 28/50
# 201/201 [==============================] - 0s 975us/step - loss: 0.1841 - accuracy: 0.9234 - val_loss: 0.2917 - val_accuracy: 0.8913
#
# Epoch 00028: val_accuracy did not improve from 0.89319
# Epoch 29/50
# 201/201 [==============================] - 0s 978us/step - loss: 0.1803 - accuracy: 0.9307 - val_loss: 0.2954 - val_accuracy: 0.8963
#
# Epoch 00029: val_accuracy improved from 0.89319 to 0.89631, saving model to dogcat_model4.h5
# Epoch 30/50
# 201/201 [==============================] - 0s 968us/step - loss: 0.1823 - accuracy: 0.9278 - val_loss: 0.2988 - val_accuracy: 0.8963
#
# Epoch 00030: val_accuracy did not improve from 0.89631
# Epoch 31/50
# 201/201 [==============================] - 0s 973us/step - loss: 0.1802 - accuracy: 0.9278 - val_loss: 0.2924 - val_accuracy: 0.8932
#
# Epoch 00031: val_accuracy did not improve from 0.89631
# Epoch 32/50
# 201/201 [==============================] - 0s 972us/step - loss: 0.1814 - accuracy: 0.9294 - val_loss: 0.2913 - val_accuracy: 0.8894
#
# Epoch 00032: val_accuracy did not improve from 0.89631
# Epoch 33/50
# 201/201 [==============================] - 0s 963us/step - loss: 0.1747 - accuracy: 0.9286 - val_loss: 0.2901 - val_accuracy: 0.8913
#
# Epoch 00033: val_accuracy did not improve from 0.89631
# Epoch 34/50
# 201/201 [==============================] - 0s 980us/step - loss: 0.1794 - accuracy: 0.9276 - val_loss: 0.2944 - val_accuracy: 0.8988
#
# Epoch 00034: val_accuracy improved from 0.89631 to 0.89881, saving model to dogcat_model4.h5
# Epoch 35/50
# 201/201 [==============================] - 0s 986us/step - loss: 0.1816 - accuracy: 0.9308 - val_loss: 0.2922 - val_accuracy: 0.8944
#
# Epoch 00035: val_accuracy did not improve from 0.89881
# Epoch 36/50
# 201/201 [==============================] - 0s 980us/step - loss: 0.1812 - accuracy: 0.9251 - val_loss: 0.2910 - val_accuracy: 0.8938
#
# Epoch 00036: val_accuracy did not improve from 0.89881
# Epoch 37/50
# 201/201 [==============================] - 0s 970us/step - loss: 0.1660 - accuracy: 0.9348 - val_loss: 0.2934 - val_accuracy: 0.8976
#
# Epoch 00037: val_accuracy did not improve from 0.89881
# Epoch 38/50
# 201/201 [==============================] - 0s 980us/step - loss: 0.1812 - accuracy: 0.9240 - val_loss: 0.2922 - val_accuracy: 0.8957
#
# Epoch 00038: val_accuracy did not improve from 0.89881
# Epoch 39/50
# 201/201 [==============================] - 0s 974us/step - loss: 0.1762 - accuracy: 0.9275 - val_loss: 0.2912 - val_accuracy: 0.8938
#
# Epoch 00039: val_accuracy did not improve from 0.89881
# Epoch 40/50
# 201/201 [==============================] - 0s 983us/step - loss: 0.1782 - accuracy: 0.9291 - val_loss: 0.2952 - val_accuracy: 0.8976
#
# Epoch 00040: val_accuracy did not improve from 0.89881
# Epoch 41/50
# 201/201 [==============================] - 0s 976us/step - loss: 0.1789 - accuracy: 0.9277 - val_loss: 0.2947 - val_accuracy: 0.8963
#
# Epoch 00041: val_accuracy did not improve from 0.89881
# Epoch 42/50
# 201/201 [==============================] - 0s 983us/step - loss: 0.1788 - accuracy: 0.9283 - val_loss: 0.2918 - val_accuracy: 0.8951
#
# Epoch 00042: val_accuracy did not improve from 0.89881
# Epoch 43/50
# 201/201 [==============================] - 0s 986us/step - loss: 0.1740 - accuracy: 0.9297 - val_loss: 0.2917 - val_accuracy: 0.8938
#
# Epoch 00043: val_accuracy did not improve from 0.89881
# Epoch 44/50
# 201/201 [==============================] - 0s 984us/step - loss: 0.1734 - accuracy: 0.9260 - val_loss: 0.2916 - val_accuracy: 0.8938
#
# Epoch 00044: val_accuracy did not improve from 0.89881
# Epoch 00044: early stopping
# test: 0.8947108387947083
# train: 0.9301998615264893
# val: 0.893816351890564
